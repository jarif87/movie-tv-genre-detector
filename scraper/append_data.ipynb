# %%
import pandas as pd

df1 = pd.read_csv("/content/movie_details.csv")
df2 = pd.read_csv("/content/movie_urls_part2.csv", encoding='latin1')
df3=pd.read_csv("/content/movie_urls_part1.csv", encoding='latin1')
df4=pd.read_csv("/content/movie_details_part1.csv")
df5=pd.read_csv("/content/modified_tv_show_details.csv")

# %%
df1.head()
# Out:
#                                                  url  \
# 0     https://www.metacritic.com/movie/the-informer/
# 1    https://www.metacritic.com/movie/reign-over-me/
# 2  https://www.metacritic.com/movie/triple-frontier/
# 3  https://www.metacritic.com/movie/somewhere-in-...
# 4  https://www.metacritic.com/movie/the-jeffrey-d...
#
#                                          description  \
# 0  Honorably discharged Special Ops soldier Pete ...
# 1  Former college roommates Charlie Fineman (Sand...
# 2  A group of former Special Forces operatives (B...
# 3  Leo Russo (Ray Romano) lives a simple life in ...
# 4  In the summer of 1991 Jeffrey Dahmer was arres...
#
#                                               genres
# 0  ['Action', 'Crime', 'Drama', 'Thriller', '', '...
# 1                             ['Drama', '', 'Drama']
# 2  ['Action', 'Thriller', '', '', 'Action', 'Thri...
# 3  ['Comedy', 'Drama', 'Sport', '', '', '', 'Come...
# 4  ['Documentary', 'Biography', 'Crime', 'Drama',...

# %%
df1.shape
# Out:
# (7771, 3)

# %%
df2.head()
# Out:
#                                                title  \
# 0  7,921. The Informer\nNOV 6, 2020   \nHonorabl...
# 1  7,922.\nMAR 23, 2007\nFormer college roommates...
# 2  7,923.\nMAR 6, 2019   \nA group of former Spe...
# 3  7,924.\nAPR 21, 2023   \nLeo Russo (Ray Roman...
# 4  7,925. The Jeffrey Dahmer Files\nFEB 15, 2013 ...
#
#                                                  url
# 0     https://www.metacritic.com/movie/the-informer/
# 1    https://www.metacritic.com/movie/reign-over-me/
# 2  https://www.metacritic.com/movie/triple-frontier/
# 3  https://www.metacritic.com/movie/somewhere-in-...
# 4  https://www.metacritic.com/movie/the-jeffrey-d...

# %%
df2.shape
# Out:
# (7920, 2)

# %%
df1["title"]=df2["title"]

# %%
df1.head()
# Out:
#                                                  url  \
# 0     https://www.metacritic.com/movie/the-informer/
# 1    https://www.metacritic.com/movie/reign-over-me/
# 2  https://www.metacritic.com/movie/triple-frontier/
# 3  https://www.metacritic.com/movie/somewhere-in-...
# 4  https://www.metacritic.com/movie/the-jeffrey-d...
#
#                                          description  \
# 0  Honorably discharged Special Ops soldier Pete ...
# 1  Former college roommates Charlie Fineman (Sand...
# 2  A group of former Special Forces operatives (B...
# 3  Leo Russo (Ray Romano) lives a simple life in ...
# 4  In the summer of 1991 Jeffrey Dahmer was arres...
#
#                                               genres  \
# 0  ['Action', 'Crime', 'Drama', 'Thriller', '', '...
# 1                             ['Drama', '', 'Drama']
# 2  ['Action', 'Thriller', '', '', 'Action', 'Thri...
# 3  ['Comedy', 'Drama', 'Sport', '', '', '', 'Come...
# ...

# %%
df3.head()
# Out:
#                                                title  \
# 0  1. Dekalog (1988)\nMAR 22, 1996\nThis masterwo...
# 1  2. The Leopard (re-release)\nAUG 13, 2004\nSet...
# 2  3. The Godfather\nMAR 24, 1972\nFrancis Ford C...
# 3  4. Tokyo Story\nMAR 13, 1972   \nYasujiro Ozu...
# 4  5. Three Colors: Red\nNOV 23, 1994\nKrzysztof ...
#
#                                                  url
# 0     https://www.metacritic.com/movie/dekalog-1988/
# 1  https://www.metacritic.com/movie/the-leopard-r...
# 2    https://www.metacritic.com/movie/the-godfather/
# 3      https://www.metacritic.com/movie/tokyo-story/
# 4  https://www.metacritic.com/movie/three-colors-...

# %%
df4.head()
# Out:
#                                                  url  \
# 0     https://www.metacritic.com/movie/dekalog-1988/
# 1  https://www.metacritic.com/movie/the-leopard-r...
# 2    https://www.metacritic.com/movie/the-godfather/
# 3      https://www.metacritic.com/movie/tokyo-story/
# 4  https://www.metacritic.com/movie/three-colors-...
#
#                                          description  \
# 0  This masterwork by Krzysztof Kieślowski is one...
# 1  Set in Sicily in 1860, Luchino Visconti's spec...
# 2  Francis Ford Coppola's epic features Marlon Br...
# 3  Yasujiro Ozu’s Tokyo Story follows an aging co...
# 4  Krzysztof Kieslowski closes his Three Colors t...
#
#                                               genres
# 0                             ['Drama', '', 'Drama']
# 1   ['Drama', 'History', '', '', 'Drama', 'History']
# 2       ['Crime', 'Drama', '', '', 'Crime', 'Drama']
# 3                             ['Drama', '', 'Drama']
# 4  ['Drama', 'Mystery', 'Romance', '', '', '', 'D...

# %%
df4["title"]=df3["title"]
df4.head()
# Out:
#                                                  url  \
# 0     https://www.metacritic.com/movie/dekalog-1988/
# 1  https://www.metacritic.com/movie/the-leopard-r...
# 2    https://www.metacritic.com/movie/the-godfather/
# 3      https://www.metacritic.com/movie/tokyo-story/
# 4  https://www.metacritic.com/movie/three-colors-...
#
#                                          description  \
# 0  This masterwork by Krzysztof Kieślowski is one...
# 1  Set in Sicily in 1860, Luchino Visconti's spec...
# 2  Francis Ford Coppola's epic features Marlon Br...
# 3  Yasujiro Ozu’s Tokyo Story follows an aging co...
# 4  Krzysztof Kieslowski closes his Three Colors t...
#
#                                               genres  \
# 0                             ['Drama', '', 'Drama']
# 1   ['Drama', 'History', '', '', 'Drama', 'History']
# 2       ['Crime', 'Drama', '', '', 'Crime', 'Drama']
# 3                             ['Drama', '', 'Drama']
# ...

# %%
df4.isnull().sum()
# Out:
# url            0
# description    0
# genres         0
# title          0
# dtype: int64

# %%
df1.isnull().sum()
# Out:
# url            0
# description    0
# genres         0
# title          0
# dtype: int64

# %%
final_df = pd.concat([df1, df4], ignore_index=True)
final_df.head()
# Out:
#                                                  url  \
# 0     https://www.metacritic.com/movie/the-informer/
# 1    https://www.metacritic.com/movie/reign-over-me/
# 2  https://www.metacritic.com/movie/triple-frontier/
# 3  https://www.metacritic.com/movie/somewhere-in-...
# 4  https://www.metacritic.com/movie/the-jeffrey-d...
#
#                                          description  \
# 0  Honorably discharged Special Ops soldier Pete ...
# 1  Former college roommates Charlie Fineman (Sand...
# 2  A group of former Special Forces operatives (B...
# 3  Leo Russo (Ray Romano) lives a simple life in ...
# 4  In the summer of 1991 Jeffrey Dahmer was arres...
#
#                                               genres  \
# 0  ['Action', 'Crime', 'Drama', 'Thriller', '', '...
# 1                             ['Drama', '', 'Drama']
# 2  ['Action', 'Thriller', '', '', 'Action', 'Thri...
# 3  ['Comedy', 'Drama', 'Sport', '', '', '', 'Come...
# ...

# %%
final_df.shape
# Out:
# (15548, 4)

# %%
df5.head()
# Out:
#                                   title  \
# 0                         We Are Family
# 1                             The Floor
# 2                          Fool Me Once
# 3  America's Got Talent: Fantasy League
# 4                     Pokémon Concierge
#
#                                                  url  \
# 0       https://www.metacritic.com/tv/we-are-family/
# 1           https://www.metacritic.com/tv/the-floor/
# 2        https://www.metacritic.com/tv/fool-me-once/
# 3  https://www.metacritic.com/tv/americas-got-tal...
# 4   https://www.metacritic.com/tv/pokemon-concierge/
#
#                                          description  \
# 0  Contestants can win up to $150,000 if they can...
# 1  Rob Lowe hosts the game show that features 81 ...
# 2  Set in England, Maya Stern (Michelle Keegan) i...
# 3  The latest America's Got Talent spin-off has e...
# 4  Haru, a new concierge at the Pokémon Resort, h...
#
#                                               genres
# ...

# %%
df5.isnull().sum()
# Out:
# title           0
# url             0
# description    51
# genres          0
# dtype: int64

# %%
df5=df5.dropna()

# %%
df5.isnull().sum()
# Out:
# title          0
# url            0
# description    0
# genres         0
# dtype: int64

# %%
df = pd.concat([final_df, df5], ignore_index=True)
df.head()
# Out:
#                                                  url  \
# 0     https://www.metacritic.com/movie/the-informer/
# 1    https://www.metacritic.com/movie/reign-over-me/
# 2  https://www.metacritic.com/movie/triple-frontier/
# 3  https://www.metacritic.com/movie/somewhere-in-...
# 4  https://www.metacritic.com/movie/the-jeffrey-d...
#
#                                          description  \
# 0  Honorably discharged Special Ops soldier Pete ...
# 1  Former college roommates Charlie Fineman (Sand...
# 2  A group of former Special Forces operatives (B...
# 3  Leo Russo (Ray Romano) lives a simple life in ...
# 4  In the summer of 1991 Jeffrey Dahmer was arres...
#
#                                               genres  \
# 0  ['Action', 'Crime', 'Drama', 'Thriller', '', '...
# 1                             ['Drama', '', 'Drama']
# 2  ['Action', 'Thriller', '', '', 'Action', 'Thri...
# 3  ['Comedy', 'Drama', 'Sport', '', '', '', 'Come...
# ...

# %%
df.shape
# Out:
# (21869, 4)

# %%
df.isnull().sum()
# Out:
# url            0
# description    0
# genres         0
# title          0
# dtype: int64

# %%
df.to_csv("movie_tvshow_description.csv",index=False)
